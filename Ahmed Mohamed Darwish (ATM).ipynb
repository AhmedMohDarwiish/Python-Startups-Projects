# %%
print("Welcome in Egypt -ATM- \n")
pin1=1234
pin2=int(input("please enter 4 digit pin code for your card "))

if pin2==pin1:
    print("\nyou entered your pin correctly ((( ",pin2,")))")
else:
    print("\nyour pin not correct((( ",pin2,")))\n")
    
    print("\n\n\nThanks For Your Service")
    
#******************************************************************************
#                               Variables
#******************************************************************************

balance=7000
withdraw=0
payin=0


#******************************************************************************

if pin2==pin1:
    print("\nPress 1 FOR YOUR balance ")
    print("\nPress 2 to Make a withdraw ")
    print("\nPress 3 FOR pay in ")
    print("\nPress 4 FOR Return ")
    
#******************************************************************************    
    
    choose=int(input("\n\n********************\n\nwhat would you like to choose "))
    if choose==1:
            print("\nYour Balance is\t(((",balance," USD)))")
            back=input("\nwould you like to go back ?? ")
            if back=="yes":
                print("\nPress 1 FOR YOUR balance ")
                print("\nPress 2 to Make a withdraw ")
                print("\nPress 3 FOR pay in ")
                print("\nPress 4 FOR Return ")

            else:
                print("\nThanks For Your Service")    

#******************************************************************************                    
                
    choose=int(input("\n\n********************\n\nwhat would you like to choose "))
    if choose==2:
            print("\nhow much you want to withdraw" )
            withdraw=int(input("\n1000 / 2000 / 3000 / 4000 / 5000 / 6000 / 7000 "))
            print("\nyour balance now is(((",(balance-withdraw)," USD)))" )
            newbalance=(balance-withdraw) 
            back=input("\nwould you like to go back ?? ")
            if back=="yes":
                print("\nPress 1 FOR YOUR balance ")
                print("\nPress 2 to Make a withdraw ")
                print("\nPress 3 FOR pay in ")
                print("\nPress 4 FOR Return ")
            else:
                print("\nThanks For Your Service")
                
#******************************************************************************    
                
    choose=int(input("\n\n********************\n\nwhat would you like to choose "))
    if choose==3:
            Payin=int(input("\nhow much you want to Pay In " ))
            print("\nyour balance now is(((",(newbalance+Payin)," USD)))" )
            back=input("\nwould you like to go back ?? ")
            if back=="yes":
                print("\nPress 1 FOR YOUR balance ")
                print("\nPress 2 to Make a withdraw ")
                print("\nPress 3 FOR pay in ")
                print("\nPress 4 FOR Return ")
                
#******************************************************************************    
                
    choose=int(input("\n\n********************\n\nwhat would you like to choose "))
    if choose==4:
            print("\n please wait while your card  is returned ..." )
            print("\n\n\nThanks For Your Service")
# Out:
# Welcome in Egypt -ATM-
#
# please enter 4 digit pin code for your card 1234
#
# you entered your pin correctly (((  1234 )))
#
# Press 1 FOR YOUR balance
#
# Press 2 to Make a withdraw
#
# Press 3 FOR pay in
#
# Press 4 FOR Return
#
#
# ********************
#
# what would you like to choose 1
#
# Your Balance is	((( 7000  USD)))
#
# would you like to go back ?? yes
#
# Press 1 FOR YOUR balance
#
# Press 2 to Make a withdraw
#
# Press 3 FOR pay in
#
# Press 4 FOR Return
#
#
# ********************
#
# what would you like to choose 2
#
# how much you want to withdraw
#
# 1000 / 2000 / 3000 / 4000 / 5000 / 6000 / 7000 3000
#
# your balance now is((( 4000  USD)))
#
# would you like to go back ?? yes
#
# Press 1 FOR YOUR balance
#
# Press 2 to Make a withdraw
#
# Press 3 FOR pay in
#
# Press 4 FOR Return
#
#
# ********************
#
# what would you like to choose 3
#
# how much you want to Pay In 5000
#
# your balance now is((( 9000  USD)))
#
# would you like to go back ?? yes
#
# ...
